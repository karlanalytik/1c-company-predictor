# %%
# Loggearse
# !aws ecr get-login-password --region us-east-1 | docker login --username AWS --password-stdin 988261566883.dkr.ecr.us-east-1.amazonaws.com
# Out:
# Login Succeeded

# %%
#Build
# !docker build -t streamlit-mvp .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 260B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        0.2s
# [+] Building 0.3s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 260B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.11-slim        0.3s
# [+] Building 0.5s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 260B                                       0.0s
# ...

# %%
#Run
# !docker run -d -p 8501:8501 streamlit-mvp
# Out:
# a729f582d502c3f327acbff105416ce24a15547ae3b60458ee2ab1463f466223

# %%
# !docker ps
# Out:
# CONTAINER ID   IMAGE           COMMAND                  CREATED         STATUS         PORTS                                         NAMES
# a729f582d502   streamlit-mvp   "streamlit run app.p…"   7 seconds ago   Up 7 seconds   0.0.0.0:8501->8501/tcp, [::]:8501->8501/tcp   vibrant_clarke

# %%
# !docker logs a729f582d502
# Out:
# ...
#
# 2026-05-01 02:04:04.902 Uvicorn server started on 0.0.0.0:8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.17.0.2:8501
#   External URL: http://201.134.132.134:8501

# %%
# Contenedores desde la nube
# !docker tag streamlit-mvp:latest 988261566883.dkr.ecr.us-east-1.amazonaws.com/streamlit-mvp:latest

# %%
# !docker push 988261566883.dkr.ecr.us-east-1.amazonaws.com/streamlit-mvp:latest
# Out:
# The push refers to repository [988261566883.dkr.ecr.us-east-1.amazonaws.com/streamlit-mvp]
#
# b66b2eed: Waiting
# bace21da: Waiting
# af2bc2a9: Waiting
# 2250c524: Waiting
# 73948dde: Waiting
# af247f90: Waiting
# 8760033c: Waiting
# a4e63694: Waiting
# b66b2eed: Pushed   1.044kB/1.044kBlatest: digest: sha256:043b4d9f4df7874c5a42dd111228fe2e5de20ab7c23d735f450f1577ad2bbd50 size: 856

# %%
Checkpoint 30/04/26
- Streamlit app built and deployed
- Docker image built locally
- Image pushed to ECR
- ECS Fargate service running with public URL
- RDS PostgreSQL created
- Security Group and public access configured
- Table feedback created
- Streamlit connected to RDS
- Feedback inserted from UI and validated in PostgreSQL

# %%
# Para verificar imagenes
# !docker images

# %%
# Para cerrar el contenedor
# !docker stop a729f582d502
# Out:
# a729f582d502
